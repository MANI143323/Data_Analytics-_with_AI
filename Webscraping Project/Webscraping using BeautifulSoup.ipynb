# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent":"Mozilla/5.0"}

for i in range(1, 11):

    url = f"https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page={i}"
    print(url)

    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "lxml")

    print("Status code:",r.status_code)
# Out:
# https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=1
# Status code: 200
# https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=2
# Status code: 200
# https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=3
# Status code: 200
# https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=4
# Status code: 200
# https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=5
# Status code: 200
# https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=6
# Status code: 200
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

Products = []
Prices = []
Descriptions = []
Reviews = []

headers = {"User-Agent":"Mozilla/5.0"}

for i in range(1, 11):
    url = f"https://www.flipkart.com/search?q=5G+mobiles+under+50k&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page={i}"
    r = requests.get(url, headers = headers)
    soup = BeautifulSoup(r.text, 'lxml')
    box = soup.find("div", class_="QSCKDh dLgFEE")
    
    names = box.find_all("div", class_="RG5Slk")
    
    for i in names:
        name = i.text
        Products.append(name)
    print("Products:",len(Products))
    
    amount = box.find_all("div", class_="hZ3P6w DeU9vF")
    
    for i in amount:
        amount = i.text
        Prices.append(amount)
    print(Prices)
    
    des = box.find_all("div",class_="CMXw7N")
    
    for i in des:
        des = i.text
        Descriptions.append(des)
    print("Descriptions:",len(Descriptions))
    
    Rev = box.find_all("div", class_="MKiFS6")
    
    for i in Rev:
        Rev = i.text
        Reviews.append(Rev)
    print("Reviews:",len(Reviews))
# Out:
# Products: 24
# ['₹47,899', '₹51,328', '₹49,999', '₹47,300', '₹49,999', '₹47,999', '₹49,990', '₹42,999', '₹41,999', '₹42,999', '₹41,999', '₹36,164', '₹41,999', '₹49,999', '₹47,999', '₹44,999', '₹49,999', '₹49,999', '₹41,999', '₹43,593', '₹42,999', '₹40,999', '₹49,999', '₹49,999']
# Descriptions: 24
# Reviews: 24
# Products: 48
# ['₹47,899', '₹51,328', '₹49,999', '₹47,300', '₹49,999', '₹47,999', '₹49,990', '₹42,999', '₹41,999', '₹42,999', '₹41,999', '₹36,164', '₹41,999', '₹49,999', '₹47,999', '₹44,999', '₹49,999', '₹49,999', '₹41,999', '₹43,593', '₹42,999', '₹40,999', '₹49,999', '₹49,999', '₹48,999', '₹40,999', '₹44,999', '₹45,999', '₹39,599', '₹49,999', '₹40,999', '₹40,999', '₹44,950', '₹42,999', '₹46,999', '₹41,999', '₹39,899', '₹36,989', '₹44,999', '₹40,999', '₹43,101', '₹44,999', '₹47,999', '₹49,999', '₹43,999', '₹36,873', '₹47,499', '₹49,999']
# Descriptions: 48
# Reviews: 48
# Products: 72
# ...

# %%
df = pd.DataFrame({
    "Products Name": pd.Series(Products),
    "Prices": pd.Series(Prices),
    "Descriptions": pd.Series(Descriptions),
    "Reviews" : pd.Series(Reviews),
})
print(df)
df.to_csv("C:/Users/Manikanta08/OneDrive/Documents/webscraping/flipkart_5Gmobiles.csv")
# Out:
#                                          Products Name   Prices  \
# 0                    IQOO 15R 5G (Dark Knight, 256 GB)  ₹47,899
# 1                 OnePlus Nord 6 (Pitch Black, 256 GB)  ₹51,328
# 2    Samsung Galaxy S24 5G Snapdragon (Amber Yellow...  ₹49,999
# 3                 IQOO 15R 5G (Triumph Silver, 256 GB)  ₹47,300
# 4    Samsung Galaxy S24 5G Snapdragon (Onyx Black, ...  ₹49,999
# ..                                                 ...      ...
# 235                POCO M7 Plus 5G (Aqua Blue, 128 GB)  ₹15,999
# 236                  vivo T5x 5G (Cyber Green, 128 GB)  ₹24,999
# 237                 OPPO K14 5G (Prism Violet, 256 GB)  ₹23,999
# 238                realme Gt 7 (Icesense Blue, 256 GB)  ₹38,999
# 239                    OnePlus 12R (Cool Blue, 256 GB)  ₹39,999
#
#                                           Descriptions Reviews
# 0    8 GB RAM | 256 GB ROM16.74 cm (6.59 inch) Disp...     4.6
# 1    12 GB RAM | 256 GB ROM | Expandable Upto 256 G...     4.7
# ...
